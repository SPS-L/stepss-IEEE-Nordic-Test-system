# %%
import pyramses
ram = pyramses.sim()
case = pyramses.cfg('cmd.txt')
ram.execSim(case)
# Out:
# ...
# ---------------------------------------------------------------------------
# RAMSESError                               Traceback (most recent call last)
# <ipython-input-1-ac005cdc544a> in <module>
#       2 ram = pyramses.sim()
#       3 case = pyramses.cfg('cmd.txt')
# ----> 4 ram.execSim(case)
#
# c:\users\p3tri\dropbox\code\pyramses_install\src\pyramses\simulator.py in execSim(self, cmd, pause)
#     322         retval = self._ramseslib.ramses(cmdfilename.encode('utf-8'), outfilename.encode('utf-8'))
#     323         if (retval != 0) and (retval != 112):
# --> 324             raise RAMSESError('RAMSES: Function execSim() failed with the flag %i. Last message was: %s' % (retval, self.getLastErr()))
#     325         return 0
#     326
#
# RAMSESError: RAMSES: Function execSim() failed with the flag -1. Last message was: ERROR CALL FROM get_sync_mach
