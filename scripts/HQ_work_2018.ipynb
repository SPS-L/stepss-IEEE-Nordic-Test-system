# %% [markdown]
# # Run simple simulation loaded from file

# %%
import PyRAMSES

# %%
ram = PyRAMSES.sim()

# %%
case = PyRAMSES.cfg('cmd.txt')
# Out:
# RAMSESWarning: The file init.trace already exists. It will be overwritten!
# RAMSESWarning: The file obs.trj already exists. It will be overwritten!
# RAMSESWarning: The file cont.trace already exists. It will be overwritten!
# RAMSESWarning: The file disc.trace already exists. It will be overwritten!

# %%
ram.initSim(case)
# Out:
# 0

# %%
ram.initPF()
# Out:
# 0

# %%
ram.initDyn()
# Out:
# 0

# %%
case.addRunObs('BV g1') # will plot in real-time the voltage on bus g1

# %%
ram.initVars()
# Out:
# 0

# %%
ram.execSim(10.0)
# Out:
# 0

# %%
busnames = ram.getAllCompNames("BUS")
print(busnames[0:3]) # print the first 3
# Out:
# ['g1', 'g2', 'g3']

# %%
ram.getBusVolt(busnames[0:3]) # returns a list of voltages in per unit
# Out:
# [1.07105602130084, 1.0596236975195783, 1.0628367568528183]

# %%
comp_type = ['EXC','EXC','EXC']
comp_name = ['g1','g2','g3'] # name of synchronous machines
ram.getPrmNames(comp_type,comp_name)
# Out:
# [['KPSS', 'V0'], ['KPSS', 'V0'], ['KPSS', 'V0']]

# %%
comp_type = ['EXC', 'EXC']
comp_name = ['g1', 'g2']
prm_name = ['V0', 'KPSS']
ram.getPrm(comp_type, comp_name, prm_name) # returns a list with parameter V0 of synchronous machine g1 and parameter KPSS of synchronous machine g2
# Out:
# [1.0900587111458164, 75.0]

# %%
comp_type = ['INJ', 'INJ']
comp_name = ['L_11', 'L_11']
obs_name = ['P', 'Q']
ram.getObs(comp_type,comp_name, obs_name)
# Out:
# [1.9963472099697763, 0.6854740161178252]

# %%
ram.addDisturb(ram.getSimTime()+0.01, 'CHGPRM EXC g1 V0 -0.05 0') # we need to pas this to the simulator since this is a discrete change
# Out:
# 0

# %%
ram.contSim(150.0)
# Out:
# 0

# %%
ram.endSim()
# Out:
# 0

# %%
del(ram)
# Out:
# RAMSESWarning: Simulator with number 1 was deleted.
