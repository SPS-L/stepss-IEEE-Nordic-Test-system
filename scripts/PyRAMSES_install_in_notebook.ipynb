# %% [markdown]
# ## Install pyramses

# %%
import sys
# !conda install --yes --prefix {sys.prefix} pyramses -c apetros

# %% [markdown]
# ## Load module

# %%
import pyramses

# %% [markdown]
# ## Check if MKL is installed. If not, RAMSES will crash

# %%
#import numpy as np
#np.__config__.show()

# %% [markdown]
# ## Load simulator

# %%
ram = pyramses.sim()

# %% [markdown]
# ## Load saved test-case

# %%
case = pyramses.cfg('cmd.txt')

# %% [markdown]
# ## Add one observation more

# %%
case.addRunObs('BV g1') # will plot in real-time the voltage on bus g1

# %% [markdown]
# ## Loop until collapse

# %%
ram.execSim(case,0.0)
# create a graph
busnames = ram.getAllCompNames("BUS")
for i in range(1,200):
    newVolt = ram.getBusVolt(busnames)
    #update_graph(newVolt)
    #visualise_new_graph()
    try:
        ram.contSim(i)
    except
