# %%
import pyramses

# %%
case = pyramses.cfg("cmd.txt") # where cmd.txt is the file with the test-case description
case.addRunObs("BV 1041")
# Out:
# RAMSESWarning: The file init.trace already exists. It will be overwritten!
# RAMSESWarning: The file cont.trace already exists. It will be overwritten!
# RAMSESWarning: The file disc.trace already exists. It will be overwritten!

# %%
ram = pyramses.sim()

# %%
ram.execSim(case)
# Out:
# ---------------------------------------------------------------------------
# RAMSESError                               Traceback (most recent call last)
# <ipython-input-4-0b154a730da9> in <module>
# ----> 1 ram.execSim(case)
#
# c:\users\eenpar\dropbox\code\pyramses\pyramses\simulator.py in execSim(self, cmd, pause)
#     243         retval = self._ramseslib.ramses(cmdfilename.encode('utf-8'), outfilename.encode('utf-8'))
#     244         if (retval != 0) and (retval != 112):
# --> 245             raise RAMSESError('RAMSES: Function execSim(%s) failed with the flag %i. Last message was: %s' % (cmdfilename, retval, self.getLastErr()))
#     246         return 0
#     247
#
# RAMSESError: RAMSES: Function execSim(C:\Users\eenpar\Dropbox\Test_Systems\Nordic_test_system\pyramses_yc2m5hxb.txt) failed with the flag -1. Last message was: ERROR CALL FROM DCTL sim_minmaxvolt MINMAXVOLT_Stopping t =  167.2200         Voltage out of bounds at bus g6 :  0.70

# %%
ram.endSim()

# %%
del(ram)
